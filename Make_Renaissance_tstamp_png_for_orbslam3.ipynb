# %% [markdown]
# time stamp가 찍힌 txt파일을 이용하여 이미지 파일 이름을 tstamp.png로 만들기
# 르네상스 데이터셋은 tstamp가 이미지 개수의 3배이기 때문

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import glob
from PIL import Image
import re

# %%
image_path = '/content/drive/MyDrive/MPIL/Astrobee/ARKit_for_Validation_Slams/Renaissance_datasets/960x720/*.png'
save_path = '/content/drive/MyDrive/MPIL/Astrobee/ARKit_for_Validation_Slams/Renaissance_datasets/960x720_t/'

# %%
files = glob.glob(image_path)

# %%
a = files[2459][93:99]
a
# Out:
# '000460'

# %%
file_name = []

inputfile = open("/content/drive/MyDrive/MPIL/Astrobee/ARKit_for_Validation_Slams/Renaissance_datasets/timestamp_renaissance_mono_euroc.txt", mode="r", encoding='UTF-8')
lines = inputfile.readlines()
for line in lines:
  tstamps = line.strip().split()
  for tstamp in tstamps:
    tstamp = re.sub("\n", "", tstamp) #remove enter
    file_name.append(tstamp)
inputfile.close()

# %%
file_name[2459]
# Out:
# '2533631372625'

# %%
# 원래 이미지가 1번이면 리스트 인덱스 0번째인 이름으로 저장
for f in files:
    f_num = int(f[93:99]) # 오리지널 파일 명 000001
    img = Image.open(f)
    img.save(save_path+file_name[f_num - 1]+'.png') # file_name 리스트에는 timestamp명이 순서대로 들어있음
