# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import glob
from PIL import Image

# %%
image_path = '/content/drive/MyDrive/MPIL/DroidSlam/Astrobee_bumble0724/bumble_0724_0938_images/bumble_0724_0938_640_t/*.png'

# %%
files = glob.glob(image_path)

# %%
txt_f = open("/content/drive/MyDrive/MPIL/DroidSlam/Astrobee_bumble0724/bumble_0724_0938_images/mono_euroc_bumble0724_0938_1e9.txt", "w")
for f in files:
    img = Image.open(f)
    title, ext = os.path.splitext(f)
    #print(title[105:])
    txt_f.write(title[105:] + "000000000" +"\n")
    #img_resize.save(save_path+title[106:]+'.png')
txt_f.close()

# %%
txt_f = open("/content/drive/MyDrive/MPIL/DroidSlam/Astrobee_bumble0724/bumble_0724_0938_images/mono_euroc_bumble0724_0938_1e9.txt", "r")
print(txt_f.read().count("\n")+1)
txt_f.close()
# Out:
# 3521
