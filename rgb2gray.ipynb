# %%
from google.colab import drive
drive.mount('/content/drive');
# Out:
# Mounted at /content/drive

# %%
from matplotlib import pyplot
import cv2
import numpy as np
import os
import glob
from PIL import Image

# %%
# %cd /content/drive/MyDrive/MPIL/Astrobee/ARKit_for_Validation_Slams/Renaissance_datasets/960x720/
# Out:
# /content/drive/MyDrive/MPIL/Astrobee/ARKit_for_Validation_Slams/Renaissance_datasets/960x720

# %%
image_path = '/content/drive/MyDrive/MPIL/Astrobee/ARKit_for_Validation_Slams/Renaissance_datasets/960x720/*.png'
save_path = '/content/drive/MyDrive/MPIL/Astrobee/ARKit_for_Validation_Slams/Renaissance_datasets/960x720_gray/'

# %%
files = glob.glob(image_path)

# %%
for f in files:
    img = Image.open(f)
    title, ext = os.path.splitext(f)
    #print(title[93:])
    imgGray = img.convert('L')
    imgGray.save(save_path+title[93:]+'.png')

# %%
img.shape[2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-91a5c4b8abe1> in <module>()
# ----> 1 img.shape[2]
#
# AttributeError: 'PngImageFile' object has no attribute 'shape'
