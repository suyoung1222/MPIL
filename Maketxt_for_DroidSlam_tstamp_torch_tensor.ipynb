# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import glob
from PIL import Image

# %%
# %cd /content/drive/Shareddrives/2023_ICRA/final_datasets/Droid,DSO,ORB/편도/bumble0401_1517_640_oneway

# !unzip -qq "/content/drive/Shareddrives/2023_ICRA/final_datasets/Droid,DSO,ORB/편도/bumble0401_1517_640_oneway/bumble0401_1517_640_oneway.zip"
# Out:
# /content/drive/Shareddrives/2023_ICRA/final_datasets/Droid,DSO,ORB/편도/bumble0401_1517_640_oneway

# %%
image_path = '/content/drive/Shareddrives/2023_ICRA/final_datasets/Droid,DSO,ORB/편도/bumble0401_1517_640_oneway/*.png'

# %%
files = glob.glob(image_path)

# %%
txt_f = open("/content/drive/Shareddrives/2023_ICRA/final_datasets/Droid,DSO,ORB/편도/timestamp_bumble0401_1517_oneway_DroidTensor.txt", "w")
for f in files:
    img = Image.open(f)
    title, ext = os.path.splitext(f)
    #print(title[100:])
    txt_f.write(title[100:] +", ")
txt_f.close()

# %%
txt_f = open("/content/drive/MyDrive/MPIL/Astrobee/Astrobee_bumble0724/bumble_0724_0928_images/timestamp_bumble0724_0928_mono_euroc.txt", "r")
print(len(txt_f.readlines()))
txt_f.close()
# Out:
# 1457
